# %%
# import the libraries we will need

import pandas as pd
import datetime
from IPython.display import display
import numpy

# %%
# import the agegraded results
#results=pd.read_fwf('../data/2017_agegraded.txt')
results=pd.read_fwf('ROTG19_Overall w AG.txt')

#results=results.drop(['Place','Div','City','St'],1)

results.head()
# Out:
#    Place              Name  Num  Age  S         City  St  Split    AG%   Time
# 0      1   Patrick Carroll   45   27  M  Schenectady  NY  10:12  81.51  20:44
# 1      2       Alex Benway   15   28  M   Queensbury  NY  10:35  80.16  21:05
# 2      3  Anthony Giuliano  103   39  M    Niskayuna  NY  10:36  83.19  21:10
# 3      4      Matt Brooker   30   28  M       Albany  NY  10:48  79.22  21:20
# 4      5     Shaun Donegan  302   33  M        Malta  NY  10:49  78.40  21:44

# %%
#results['Name']=results['FIRST NAME']+' '+results['LAST NAME']

# %%
results.head()
# Out:
#    Place              Name  Num  Age  S         City  St  Split    AG%   Time
# 0      1   Patrick Carroll   45   27  M  Schenectady  NY  10:12  81.51  20:44
# 1      2       Alex Benway   15   28  M   Queensbury  NY  10:35  80.16  21:05
# 2      3  Anthony Giuliano  103   39  M    Niskayuna  NY  10:36  83.19  21:10
# 3      4      Matt Brooker   30   28  M       Albany  NY  10:48  79.22  21:20
# 4      5     Shaun Donegan  302   33  M        Malta  NY  10:49  78.40  21:44

# %%
def fixtime(ts):
    ts=str(ts)
    split=ts.split(':')
    
    try:
        return split[0]+':'+split[1]
    except:
        return "59:59"

# %%
results.Name.head()
# Out:
# 0     Patrick Carroll
# 1         Alex Benway
# 2    Anthony Giuliano
# 3        Matt Brooker
# 4       Shaun Donegan
# Name: Name, dtype: object

# %%
#results['Time']=results['Time'].apply(lambda x:fixtime(x))
results.Name=results.Name.apply(lambda x:x.upper())
#results=results.drop(['City','State'],1)
results.head()
# Out:
#    Place              Name  Num  Age  S         City  St  Split    AG%   Time
# 0      1   PATRICK CARROLL   45   27  M  Schenectady  NY  10:12  81.51  20:44
# 1      2       ALEX BENWAY   15   28  M   Queensbury  NY  10:35  80.16  21:05
# 2      3  ANTHONY GIULIANO  103   39  M    Niskayuna  NY  10:36  83.19  21:10
# 3      4      MATT BROOKER   30   28  M       Albany  NY  10:48  79.22  21:20
# 4      5     SHAUN DONEGAN  302   33  M        Malta  NY  10:49  78.40  21:44

# %%
# define a function that converts a string to a time delta
def convert(timeString): 
    try:
        #print(timeString)
        time=datetime.datetime.strptime(timeString,'%M:%S')
    except:
        time=datetime.datetime.strptime(timeString,'%M:%S.%f')
        
    # subtract the python based time to make it a time delta and return
    return time-datetime.datetime.strptime('00:00.0','%M:%S.%f')

# %%
def roundtime(t):
    mil=datetime.timedelta(microseconds=t.microseconds)
    roundmil=1000000*round(t.microseconds/1000000.)
    return t-mil+datetime.timedelta(microseconds=roundmil)

# %%
def agegrade(time, agegrade):
    return datetime.timedelta(seconds=time.total_seconds()/(.01*agegrade))

# %%
basetime=convert('16:54')
print (type(basetime))
print (basetime)
print (basetime*100/1000)
print (type(1000))
agetime= (agegrade(basetime, 82.98))
print (type(agetime))
print (agetime)
print (agetime-datetime.timedelta(microseconds=agetime.microseconds))
print (roundtime(agetime))
# Out:
# <class 'datetime.timedelta'>
# 0:16:54
# 0:01:41.400000
# <class 'int'>
# <class 'datetime.timedelta'>
# 0:20:21.981200
# 0:20:21
# 0:20:22

# %%
results.Time = results.Time.apply(lambda x: convert(x))
# create time delta by subtracting a base time
results['TimeAG']=results['AG%'].apply(lambda x:agegrade(basetime, x))
results['TimeAG']=results['TimeAG'].apply(lambda x:roundtime(x))

#imedelta(seconds=multiplier * passed_time.total_seconds())
results.iloc[0:30]
# Out:
#     Place                 Name  Num  Age  S          City  St  Split    AG%  \
# 0       1      PATRICK CARROLL   45   27  M   Schenectady  NY  10:12  81.51
# 1       2          ALEX BENWAY   15   28  M    Queensbury  NY  10:35  80.16
# 2       3     ANTHONY GIULIANO  103   39  M     Niskayuna  NY  10:36  83.19
# 3       4         MATT BROOKER   30   28  M        Albany  NY  10:48  79.22
# 4       5        SHAUN DONEGAN  302   33  M         Malta  NY  10:49  78.40
# 5       6         JAKE STOOKEY  264   42  M  Clifton Park  NY  11:11  82.33
# 6       7         AARON LOZIER  164   30  M        Albany  NY  10:45  76.98
# 7       8         DANIEL JORDY  137   35  M     Glenville  NY  11:03  77.62
# 8       9       THOMAS O'GRADY  210   33  M  Slingerlands  NY  11:03  76.53
# 9      10          CHUCK TERRY  273   36  M        Albany  NY  11:23  76.52
# 10     11       AARON KNOBLOCH  148   42  M     Niskayuna  NY  11:24  79.31
# 11     12        BRADLEY LEWIS  158   32  M          Troy  NY  11:36  74.46
# 12     13      JOSEPH SULLIVAN  267   40  M   Schenectady  NY  11:33  77.46
# 13     14        MATT NINNEMAN  206   26  M        Albany  NY  11:35  72.84
# 14     15  TUCKER CHRAPOWITZKY   54   41  M  Slingerlands  NY  11:43  76.97
# 15     16       KAREN BERTASSO   18   34  F        Albany  NY  11:39  81.49
# 16     17       MICHAEL COOLEY   61   39  M        Delmar  NY  12:07  74.46
# 17     18      JONATHAN LOUDEN  162   34  M       Clifton  NY  11:56  72.02
# 18     19        BEN GREENBERG  110   50  M  Slingerlands  NY  11:44  80.37
# 19     20     TREVOR DZIKOWICZ  305   15  M     Amsterdam  NY  11:46  73.08
# 20     21     MICHAEL DINICOLA   74   44  M         Malta  NY  12:01  76.19
# 21     22       MATTHEW CONANT  314   43  M  Ballston Spa  NY  12:07  75.15
# 22     23      CHRISTINE MYERS  196   21  F      Altamont  NY  11:52  79.30
# 23     24  CHRISTOPHER MCCLOSK  172   37  M      Glenmont  NY  12:08  71.63
# 24     25         SARA BUCKLEY   37   24  F  Slingerlands  NY  11:58  78.70
# 25     26        MATTHEW GOKEY  106   45  M        Delmar  NY  12:15  75.57
# 26     27            ANDY REED  232   47  M     Niskayuna  NY  12:05  76.48
# 27     28     NICOLE MOSLANDER  252   31  F        Albany  NY  12:16  78.13
# 2    Willow3  Anthony Giuliano     Meghan Mortensen     Nancy J. Briskie
# 3    Willow4   Patrick Carroll         Tricia Longo      Joseph Sullivan
# 4    Willow5     Bradley Lewis           Erin Lopez          Sally Drake
# 5  PeggyTeam      Anthony Lupo        Virginia Lupo         Lauren Herbs
# 6   Anything      Aaron Lozier     Nicole Moslander          Tina Greene
# 7  Scrambled     Shaun Donegan      Olivia Beltrani  Diana Tobon-Knobloc
# 8      Sweat     Matt Ninneman  Christie Macfarlane           Laura Zima
# 9    Because    Aaron Knobloch          Erin Hatton           Lisa Chase
#
#          Agegraded2           Extra 1       Extra 2   Unnamed: 7
# 0      Beth Stalker   Martha Degrazia           NaN          NaN
# 1     Ben Greenberg       Erin Murphy           NaN          NaN
# 2  John Stadtlander  Nancy J. Briskie  Daniel Jordy  Anne Benson
# 3        Judy Guzzo      Chuck Terry     Janne Rand          NaN
# 4         Andy Reed      Robert Irwin    Frank Horn          NaN
# 5  Margaret McKeown               NaN           NaN          NaN
# 6  Michael DiNicola               NaN           NaN          NaN
# 7    Paul Partridge       Renee Tolan           NaN          NaN
# 8        Ben Heller       Ed Hampston           NaN          NaN
# 9   Michelle Merlis   Randall Cannell           NaN          NaN

# %%
display(results.head())

print ('Beth Staflker' in results.Name.tolist())
print (results.Name.iloc[2]=='Beth Stalker')
7 in [1,2,3,7]
# Out:
#    Place              Name  Num  Age  S         City  St  Split    AG%  \
# 0      1   PATRICK CARROLL   45   27  M  Schenectady  NY  10:12  81.51
# 1      2       ALEX BENWAY   15   28  M   Queensbury  NY  10:35  80.16
# 2      3  ANTHONY GIULIANO  103   39  M    Niskayuna  NY  10:36  83.19
# 3      4      MATT BROOKER   30   28  M       Albany  NY  10:48  79.22
# 4      5     SHAUN DONEGAN  302   33  M        Malta  NY  10:49  78.40
#
#       Time   TimeAG
# 0 00:20:44 00:20:44
# 1 00:21:05 00:21:05
# 2 00:21:10 00:20:19
# 3 00:21:20 00:21:20
# 4 00:21:44 00:21:33
# False
# False
# True

# %%
team_dfs=pd.DataFrame(columns=('time','teamdf','name'))
team_dfs_invalid=[]

j=0;

for index, team in teams.iterrows():
#for team in teams:
    team_df=pd.DataFrame()
    #print team
    for i in range(4):
        name=team.iloc[i+1]
        name=name.upper()
        if (name in results.Name.tolist()):
            team_df=team_df.append(results.loc[results['Name']==name])
        
    team_df=team_df.reset_index(drop=True)
   
    if (team_df.shape[0]>=4):
        team_df['ScoredTime']=pd.Series([team_df.Time.iloc[0],team_df.Time.iloc[1],team_df.TimeAG.iloc[2],team_df.TimeAG.iloc[3]])
        display(team_df)
        print (team_df.ScoredTime.sum())
    
        print (team['Team Name'])
        team_dfs.loc[j]=[team_df.ScoredTime.sum(), team_df, team['Team Name']]
    else:
        team_dfs_invalid.append(team_df)
        print ("Problem!!!!!")
        display(team_df)
    
    j=j+1
# Out:
#    Place            Name  Num  Age  S          City  St  Split    AG%  \
# 0      4    MATT BROOKER   30   28  M        Albany  NY  10:48  79.22
# 2     83           LAURA ZIMA  297   38  F  Albany  NY  14:07  68.34 00:28:31
# 3     29           BEN HELLER  120   30  M    Troy  NY  12:07  68.74 00:24:37
#
#     TimeAG ScoredTime
# 0 00:23:12   00:23:12
# 1 00:21:53   00:24:48
# 2 00:24:44   00:24:44
# 3 00:24:35   00:24:35
#    Place              Name  Num  Age  S          City  St  Split    AG%  \
# 0    134      ANTHONY LUPO  165   56  M  Ballston Spa  NY  16:35  61.52
# 1    120     VIRGINIA LUPO  166   47  F         Malta  NY  15:42  66.56
# 2    138      LAUREN HERBS  122   57  F       Rexford  NY  16:33  71.08
# 3    106  MARGARET MCKEOWN  176   61  F        Moreau  NY  15:07  81.88
#
#       Time   TimeAG ScoredTime
# 0 00:32:40 00:27:28   00:32:40
# 1 00:31:16 00:25:23   00:31:16
# 2 00:32:50 00:23:47   00:23:47
# 3 00:29:58 00:20:38   00:20:38

# %%
def getFormatingRight(t):
    s=t.seconds
    hours = s // 3600 
    # remaining seconds
    s = s - (hours * 3600)
    # minutes
    minutes = s // 60
    # remaining seconds
    seconds = s - (minutes * 60)
    # total time
    return "{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds)
    #return '%s:%s:%s' % (hours, minutes, seconds)

# %%
money=['$300','$200','$100','$75','$50', '$35','$25','','','','','','']

page='Prize money awarded to top 7 teams '
#page=results.to_html()
i=0
for index, row in team_dfs.iterrows():
    
    if i%3==0 and i!=0:
        page=page+'<div class="pagebreak"> </div>'
    
    
    page=page+'<p>'
    page=page+'<br><br>'
    
    print (getFormatingRight(row.time))
    page=page+str(i+1)+'. '+money[i]+' '+row['name']+' '+getFormatingRight(row.time)+'<br>'
    page=page+row['teamdf'].to_html()
    page=page+'</p>'
    
    
    i=i+1

for df in team_dfs_invalid:
    page=page+'<p>'
    page=page+'<br><br>'
    page=page+'INCOMPLETE TEAM<br>'
    page=page+df.to_html()
    page=page+'</p>'
# Out:
# 01:25:09.00
# 01:27:14.00
# 01:27:52.00
# 01:30:02.00
# 01:31:16.00
# 01:31:47.00
# 01:33:42.00
# 01:35:00.00
# 01:37:19.00
# 01:48:21.00

# %%
page
temp=open("teams2019.html","w")
temp.write(page)
temp.close()

# %%
from weasyprint import HTML
HTML(string=page).write_pdf("report2019.pdf", stylesheets=["stylesheet.css"])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-147-b7fbf521aed5> in <module>()
# ----> 1 from weasyprint import HTML
#       2 HTML(string=page).write_pdf("report2019.pdf", stylesheets=["stylesheet.css"])
#
# c:\Users\bnorthan\Anaconda3\lib\site-packages\weasyprint\__init__.py in <module>()
#     391
#     392 # Work around circular imports.
# --> 393 from .css import preprocess_stylesheet  # noqa
#     394 from .html import (
#     395     find_base_url, HTML5_UA_STYLESHEET, HTML5_PH_STYLESHEET,
#
# c:\Users\bnorthan\Anaconda3\lib\site-packages\weasyprint\css\__init__.py in <module>()
#      24 import tinycss2
#      25
# ---> 26 from . import computed_values
#      27 from . import properties
#      28 from .properties import INITIAL_NOT_COMPUTED
#
# c:\Users\bnorthan\Anaconda3\lib\site-packages\weasyprint\css\computed_values.py in <module>()
#      15 from tinycss2.color3 import parse_color
#      16
# ---> 17 from .. import text
#      18 from ..logger import LOGGER
#      19 from ..urls import get_link_attribute
#
# c:\Users\bnorthan\Anaconda3\lib\site-packages\weasyprint\text.py in <module>()
#      12 import re
#      13
# ---> 14 import cairocffi as cairo
#      15 import cffi
#      16 import pyphen
#
# c:\Users\bnorthan\Anaconda3\lib\site-packages\cairocffi\__init__.py in <module>()
#      37
#      38
# ---> 39 cairo = dlopen(ffi, 'cairo', 'cairo-2', 'cairo-gobject-2', 'cairo.so.2')
#      40
#      41
#
# c:\Users\bnorthan\Anaconda3\lib\site-packages\cairocffi\__init__.py in dlopen(ffi, *names)
#      34             except OSError:
#      35                 pass
# ---> 36     raise OSError("dlopen() failed to load a library: %s" % ' / '.join(names))
#      37
#      38
#
# OSError: dlopen() failed to load a library: cairo / cairo-2 / cairo-gobject-2 / cairo.so.2

# %%
agegraded=results.to_html()
HTML(string=agegraded).write_pdf("agegraded.pdf", stylesheets=["stylesheet.css"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-225-d053c3a9ab8c> in <module>()
#       1 agegraded=results.to_html()
# ----> 2 HTML(string=agegraded).write_pdf("agegraded.pdf", stylesheets=["stylesheet.css"])
#
# NameError: name 'HTML' is not defined

# %%
f = open('report.html', 'w')
f.write(page.encode('utf8'))
f.close()

# %%
results.rename(columns={'Agegrd%': 'AG%'}, inplace=True)

for df in team_dfs:
    df.rename(columns={'Agegrd%': 'AG%'}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-21a7656467f7> in <module>()
#       2
#       3 for df in team_dfs:
# ----> 4     df.rename(columns={'Agegrd%': 'AG%'}, inplace=True)
#
# AttributeError: 'str' object has no attribute 'rename'

# %%
age_table=pd.read_csv('agegradedtable.csv')

# %%
age_table.shape
# Out:
# (96, 21)

# %%
age_table.columns
# Out:
# Index([u'Age', u'5 km', u'6 km', u'4 Mile', u'8 km', u'5 Mile', u'10 km',
#        u'12 km', u'15 km', u'10 Mile', u'20 km', u'H. Mar', u'25 km', u'30 km',
#        u'Marathon', u'50 km', u'50 Mile', u'100 km', u'150 km', u'100 Mile',
#        u'200 km'],
#       dtype='object')

# %%
four_mile=age_table['4 Mile']

# %%
four_mile.head()
# Out:
# 0    1549
# 1    1465
# 2    1394
# 3    1334
# 4    1282
# Name: 4 Mile, dtype: int64

# %%
1011./60.
# Out:
# 16.85

# %%
print 1225./60.
print .4*60
# Out:
# 20.4166666667
# 24.0

# %%
thetime=datetime.datetime.strptime('20:24','%M:%S')-datetime.datetime.strptime('00:00.0','%M:%S.%f')
print thetime
# Out:
# 0:20:24

# %%
print agegrade(thetime, 99)
# Out:
# 0:20:36.363636

# %%
basetime=convert('16:54')-datetime.datetime.strptime('00:00.0','%M:%S.%f')

# %%
type(basetime)
# Out:
# datetime.timedelta

# %%
type(convert('16:54'))
# Out:
# datetime.datetime

# %%
type(convert('16:54')-datetime.datetime.strptime('00:00.0','%M:%S.%f'))
# Out:
# datetime.timedelta
