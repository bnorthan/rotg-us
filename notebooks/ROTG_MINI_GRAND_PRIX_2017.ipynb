# %%
# import the libraries we will need

import pandas as pd
import datetime
from IPython.display import display
import numpy

# %%
# import the agegraded results
#results=pd.read_fwf('../data/2017_agegraded.txt')
results=pd.read_csv('ROTG_AgeGradedR2.csv')

#results=results.drop(['Place','Div','City','St'],1)

results.head()
# Out:
#    Place            Name  Age Sex           City State      Time  Agegrd%
# 0      1  Derrick Staley   58   M  Ballston Lake    NY     23:45    86.04
# 1      2    Beth Stalker   57   F    Burnt Hills    NY  27:14:00    85.70
# 2      3   Lori Kingsley   51   F          Wysox    PA  25:54:00    83.97
# 3      4   Mollie Turner   37   F   Averill Park    NY     23:18    83.30
# 4      5    Matt Brooker   25   M         Albany    NY     20:21    83.05

# %%
def fixtime(ts):
    ts=str(ts)
    split=ts.split(':')
    
    try:
        return split[0]+':'+split[1]
    except:
        return "59:59"

# %%
results['Time']=results['Time'].apply(lambda x:fixtime(x))
results.Name=results.Name.apply(lambda x:x.upper())
results=results.drop(['City','State'],1)
results.head()
# Out:
#    Place            Name  Age Sex   Time  Agegrd%
# 0      1  DERRICK STALEY   58   M  23:45    86.04
# 1      2    BETH STALKER   57   F  27:14    85.70
# 2      3   LORI KINGSLEY   51   F  25:54    83.97
# 3      4   MOLLIE TURNER   37   F  23:18    83.30
# 4      5    MATT BROOKER   25   M  20:21    83.05

# %%
# define a function that converts a string to a time delta
def convert(timeString): 
    try:
        time=datetime.datetime.strptime(timeString,'%M:%S')
    except:
        time=datetime.datetime.strptime(timeString,'%M:%S.%f')
        
    # subtract the python based time to make it a time delta and return
    return time-datetime.datetime.strptime('00:00.0','%M:%S.%f')

# %%
def roundtime(t):
    mil=datetime.timedelta(microseconds=t.microseconds)
    roundmil=1000000*round(t.microseconds/1000000.)
    return t-mil+datetime.timedelta(microseconds=roundmil)

# %%
def agegrade(time, agegrade):
    return datetime.timedelta(seconds=time.total_seconds()/(.01*agegrade))

# %%
basetime=convert('16:54')
print type(basetime)
print basetime
print basetime*100/1000
print type(1000)
agetime= agegrade(basetime, 82.98)
print type(agetime)
print agetime
print agetime-datetime.timedelta(microseconds=agetime.microseconds)
print roundtime(agetime)
# Out:
# <type 'datetime.timedelta'>
# 0:16:54
# 0:01:41.400000
# <type 'int'>
# <type 'datetime.timedelta'>
# 0:20:21.981200
# 0:20:21
# 0:20:22

# %%
results.Time = results.Time.apply(lambda x: convert(x))
# create time delta by subtracting a base time
results['TimeAG']=results['Agegrd%'].apply(lambda x:agegrade(basetime, x))
results['TimeAG']=results['TimeAG'].apply(lambda x:roundtime(x))

#imedelta(seconds=multiplier * passed_time.total_seconds())
results.iloc[0:30]
# Out:
#     Place              Name  Age Sex     Time  Agegrd%   TimeAG
# 0       1    DERRICK STALEY   58   M 00:23:45    86.04 00:19:39
# 1       2      BETH STALKER   57   F 00:27:14    85.70 00:19:43
# 2       3     LORI KINGSLEY   51   F 00:25:54    83.97 00:20:08
# 3       4     MOLLIE TURNER   37   F 00:23:18    83.30 00:20:17
# 4       5      MATT BROOKER   25   M 00:20:21    83.05 00:20:21
# 106    107         PAUL FLAYTER   38    M 00:26:42    65.48 00:25:49
# 107    108    ROBERT SOMERVILLE   63    M 00:32:35    65.48 00:25:49
# 108    109            KIM SCOTT   47    F 00:31:51    65.34 00:25:52
# 109    110           ROY MOWREY   58    M 00:31:18    65.29 00:25:53

# %%
teams=pd.read_csv('teams.csv')

display(teams.head())
print teams.iloc[1,3]
# define the teams
#teams.append(['team_one', 'Eric Macknight', 'Mollie Turner', 'Bob Giambalvo', 'Volker Burkowski'])
#teams.append(['team_two', 'Aaron Lozier', 'Julia Flower', 'John Stadtlander', 'Lee Pollock'])
#teams.append(['team_clue', 'Shaun Donegan', 'Erin Corcoran', 'Kim Law', 'Beth Stalker'])
#teams.append(['team_four', 'Tom Law', 'Eiko Bogue', 'Chester Tumidajewi', 'Anny Stockman'])
# Out:
#          Team Name         Open Male     Open Female      Agegraded1  \
# 0      Noonan_Team     Shaun Donegan   Meghan Louden     John Noonan
# 1        Team Loco   Joseph Sullivan  Kelly Sullivan   Steven Nicoll
# 2  WillowStreetAC1      Matt Brooker   Mollie Turner  Derrick Staley
# 3  WillowStreetAC2         Dan Jordy  Hannah Brooker       Kari Deer
# 4  WillowStreetAC3  John Stadtlander      Erin Lopez   Lori Kingsley
#
#                Agegraded2      Extra 1  Extra 2
# 0         Stephanie Landy          NaN      NaN
# 1             Sara Madden          NaN      NaN
# 2            Beth Stalker   Janne Rand      NaN
# 3  Colleen Ottalagano-Mcg  Liz Chauhan      NaN
# 4      Danielle Maslowsky  Chuck Terry      NaN
# Steven Nicoll

# %%
display(results.head())

print 'Beth Staflker' in results.Name.tolist()
print results.Name.iloc[2]=='Beth Stalker'
7 in [1,2,3,7]
# Out:
#    Place            Name  Age Sex     Time  Agegrd%   TimeAG
# 0      1  DERRICK STALEY   58   M 00:23:45    86.04 00:19:39
# 1      2    BETH STALKER   57   F 00:27:14    85.70 00:19:43
# 2      3   LORI KINGSLEY   51   F 00:25:54    83.97 00:20:08
# 3      4   MOLLIE TURNER   37   F 00:23:18    83.30 00:20:17
# 4      5    MATT BROOKER   25   M 00:20:21    83.05 00:20:21
# False
# False
# True

# %%
team_dfs=pd.DataFrame(columns=('time','teamdf','name'))
team_dfs_invalid=[]

j=0;

for index, team in teams.iterrows():
#for team in teams:
    team_df=pd.DataFrame()
    #print team
    for i in range(4):
        name=team.iloc[i+1]
        name=name.upper()
        if (name in results.Name.tolist()):
            team_df=team_df.append(results.loc[results['Name']==name])
        
    team_df=team_df.reset_index(drop=True)
   
    if (team_df.shape[0]>=4):
        team_df['ScoredTime']=pd.Series([team_df.Time.iloc[0],team_df.Time.iloc[1],team_df.TimeAG.iloc[2],team_df.TimeAG.iloc[3]])
        display(team_df)
        print team_df.ScoredTime.sum()
    
        print team['Team Name']
        team_dfs.loc[j]=[team_df.ScoredTime.sum(), team_df, team['Team Name']]
    else:
        team_dfs_invalid.append(team_df)
        print "Problem!!!!!"
        display(team_df)
    
    j=j+1
# Out:
#    Place             Name  Age Sex     Time  Agegrd%   TimeAG  ScoredTime
# 
:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds)
    #return '%s:%s:%s' % (hours, minutes, seconds)

# %%
money=['$300','$200','$100','$75','(Kingsley not HMRRC)', '$50', '$35','(Tarrier not HMRRC)', '(J./K. Sullivan not HMRRC)' ,'$25','','','','','','']

page='Prize money awarded to top 7 teams composed of entirely HMRRC members'
#page=results.to_html()
i=0
for index, row in team_dfs.iterrows():
    
    if i%3==0 and i!=0:
        page=page+'<div class="pagebreak"> </div>'
    
    
    page=page+'<p>'
    page=page+'<br><br>'
    
    print getFormatingRight(row.time)
    page=page+str(i+1)+'. '+money[i]+' '+row['name']+' '+getFormatingRight(row.time)+'<br>'
    page=page+row['teamdf'].to_html()
    page=page+'</p>'
    
    
    i=i+1

for df in team_dfs_invalid:
    page=page+'<p>'
    page=page+'<br><br>'
    page=page+'INCOMPLETE TEAM<br>'
    page=page+df.to_html()
    page=page+'</p>'
# Out:
# 01:23:01.00
# 01:30:30.00
# 01:31:11.00
# 01:32:05.00
# 01:33:01.00
# 01:37:03.00
# 01:37:28.00
# 01:47:42.00
# 01:49:48.00
# 01:50:03.00
# 01:58:34.00
# 02:09:25.00

# %%
from weasyprint import HTML
HTML(string=page).write_pdf("report.pdf", stylesheets=["stylesheet.css"])

# %%
agegraded=results.to_html()
HTML(string=agegraded).write_pdf("agegraded.pdf", stylesheets=["stylesheet.css"])

# %%
f = open('report.html', 'w')
f.write(page.encode('utf8'))
f.close()

# %%
results.rename(columns={'Agegrd%': 'AG%'}, inplace=True)

for df in team_dfs:
    df.rename(columns={'Agegrd%': 'AG%'}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-21a7656467f7> in <module>()
#       2
#       3 for df in team_dfs:
# ----> 4     df.rename(columns={'Agegrd%': 'AG%'}, inplace=True)
#
# AttributeError: 'str' object has no attribute 'rename'

# %%
age_table=pd.read_csv('agegradedtable.csv')

# %%
age_table.shape
# Out:
# (96, 21)

# %%
age_table.columns
# Out:
# Index([u'Age', u'5 km', u'6 km', u'4 Mile', u'8 km', u'5 Mile', u'10 km',
#        u'12 km', u'15 km', u'10 Mile', u'20 km', u'H. Mar', u'25 km', u'30 km',
#        u'Marathon', u'50 km', u'50 Mile', u'100 km', u'150 km', u'100 Mile',
#        u'200 km'],
#       dtype='object')

# %%
four_mile=age_table['4 Mile']

# %%
four_mile.head()
# Out:
# 0    1549
# 1    1465
# 2    1394
# 3    1334
# 4    1282
# Name: 4 Mile, dtype: int64

# %%
1011./60.
# Out:
# 16.85

# %%
print 1225./60.
print .4*60
# Out:
# 20.4166666667
# 24.0

# %%
thetime=datetime.datetime.strptime('20:24','%M:%S')-datetime.datetime.strptime('00:00.0','%M:%S.%f')
print thetime
# Out:
# 0:20:24

# %%
print agegrade(thetime, 99)
# Out:
# 0:20:36.363636

# %%
basetime=convert('16:54')-datetime.datetime.strptime('00:00.0','%M:%S.%f')

# %%
type(basetime)
# Out:
# datetime.timedelta

# %%
type(convert('16:54'))
# Out:
# datetime.datetime

# %%
type(convert('16:54')-datetime.datetime.strptime('00:00.0','%M:%S.%f'))
# Out:
# datetime.timedelta
